# %% [markdown]
# ## A simple calculator using functions
#
# 1) Read code and discuss - ask questions!
#
# 2) Comment code
#
# 3) Extend the calculator with 5 more functions

# %%
def mainMenu():
    validChoices = ["A", "S", "M","D","P"]
    valid = False
    while not valid:
        print("A)dd numbers")
        print("S)ubtract numbers")
        print("M)ultiply numbers")
        print("D)ivide numbers")
        print("P)ower")
        choice = input("choose your option").upper()
        if choice not in validChoices:
            print("sorry that is not a valid menu choice ")
        else:
            valid= True
            
    return choice
    

def enterNumber():
    valid = False
    while not valid:
        try:
            x=int(input("enter the first number"))
            valid=True
        except ValueError:
            print("That was not a valid number.. please try again")
    
    return x

def add(x,y):
    
    return x+y

def subtract(x,y):
    
    return x-y

def multiply(x,y):
    
    return x*y

def divide(x,y):
    
    return x/y

def power(x,y):
    
    return x**y

#main program starts here
print("welcome to my calculator")
again = "y"
while again == "y":
    
    userChoice = mainMenu()
    if userChoice == "A":
        answer = add(enterNumber(), enterNumber())
    elif userChoice == "S":
        answer = subtract(enterNumber(), enterNumber())
    elif userChoice == "M":
        answer = multiply(enterNumber(), enterNumber())
    elif userChoice == "D":
        answer = divide(enterNumber(), enterNumber())
    elif userChoice == "P":
        answer = power(enterNumber(), enterNumber())
    else:
        print("error - we should never get here")
    
    print("the answer from your calcaulation is="+str(answer))
# Out:
# welcome to my calculator
# A)dd numbers
# S)ubtract numbers
# M)ultiply numbers
# D)ivide numbers
# P)ower
# choose your optionp
# enter the first number6
# enter the first number6
# the answer from your calcaulation is=46656
# A)dd numbers
# S)ubtract numbers
# M)ultiply numbers
# D)ivide numbers
# P)ower
# choose your optionp
# enter the first number6
# enter the first number3
# the answer from your calcaulation is=216
# A)dd numbers
# S)ubtract numbers
# M)ultiply numbers
# D)ivide numbers
# P)ower
